# %%
from langgraph.graph import END, START, StateGraph
from langgraph.types import Send, interrupt, Command
from typing import TypedDict
import subprocess
from openai import OpenAI
import textwrap
from langchain.chat_models import init_chat_model
from typing_extensions import Annotated
import operator
import base64
from langgraph.checkpoint.memory import InMemorySaver

memory = InMemorySaver()

llm = init_chat_model("openai:gpt-4o-mini")


class State(TypedDict):

    video_file: str
    audio_file: str
    transcription: str
    summaries: Annotated[list[str], operator.add]
    thumbnail_prompts: Annotated[list[str], operator.add]
    thumbnail_sketches: Annotated[list[str], operator.add]
    final_summary: str
    user_feedback: str
    chosen_prompt: str

# %%
def extract_audio(state: State):
    output_file = state["video_file"].replace("mp4", "mp3")
    command = [
        "ffmpeg",
        "-i",
        state["video_file"],
        "-filter:a",
        "atempo=2.0",
        "-y",
        output_file,
    ]
    subprocess.run(command)
    return {
        "audio_file": output_file,
    }


def transcribe_audio(state: State):
    client = OpenAI()
    with open(state["audio_file"], "rb") as audio_file:
        transcription = client.audio.transcriptions.create(
            model="whisper-1",
            response_format="text",
            file=audio_file,
            language="ko",
            prompt="생수,손잡이,거름망,보리,알갱이,보리차",
        )
        return {
            "transcription": transcription,
        }

# %%
def dispatch_summarizers(state: State):
    transcription = state["transcription"]
    chunks = []
    for i, chunk in enumerate(textwrap.wrap(transcription, 500)):
        chunks.append({"id": i + 1, "chunk": chunk})
    return [Send("summarize_chunk", chunk) for chunk in chunks]


def summarize_chunk(chunk):
    chunk_id = chunk["id"]
    chunk = chunk["chunk"]

    response = llm.invoke(
        f"""
        Please summarize the following text.

        Text: {chunk}
        """
    )
    summary = f"[Chunk {chunk_id}] {response.content}"
    return {
        "summaries": [summary],
    }

# %%
def mega_summary(state: State):

    all_summaries = "\n".join(state["summaries"])

    prompt = f"""
        You are given multiple summaries of different chunks from a video transcription.

        Please create a comprehensive final summary that combines all the key points.

        Individual summaries:

        {all_summaries}
    """

    response = llm.invoke(prompt)

    return {
        "final_summary": response.content,
    }


def dispatch_artists(state: State):
    return [
        Send(
            "generate_thumbnails",
            {
                "id": i,
                "summary": state["final_summary"],
            },
        )
        for i in [1, 2, 3, 4, 5]
    ]


def generate_thumbnails(args):
    concept_id = args["id"]
    summary = args["summary"]

    prompt = f"""
    Based on this video summary, create a detailed visual prompt for a YouTube thumbnail.

    Create a detailed prompt for generating a thumbnail image that would attract viewers. Include:
        - Main visual elements
        - Color scheme
        - Text overlay suggestions (Korean Text)
        - Overall composition
    
    Summary: {summary}
    """

    response = llm.invoke(prompt)

    thumbnail_prompt = response.content

    client = OpenAI()

    result = client.images.generate(
        model="gpt-image-1",
        prompt=thumbnail_prompt,
        quality="low",
        moderation="low",
        size="auto",
    )

    image_bytes = base64.b64decode(result.data[0].b64_json)

    filename = f"thumbnail_{concept_id}.jpg"

    with open(filename, "wb") as file:
        file.write(image_bytes)

    return {
        "thumbnail_prompts": [thumbnail_prompt],
        "thumbnail_sketches": [filename],
    }

# %%
def human_feedback(state: State):
    answer = interrupt(
        {
            "chosen_thumbnail": "Which thumbnail do you like the most?",
            "feedback": "Provide any feedback or changes you'd like for the final thumbnail.",
        }
    )
    user_feedback = answer["user_feedback"]
    chosen_prompt = answer["chosen_prompt"]
    return {
        "user_feedback": user_feedback,
        "chosen_prompt": state["thumbnail_prompts"][chosen_prompt - 1],
    }


def generate_hd_thumbnail(state: State):

    chosen_prompt = state["chosen_prompt"]
    user_feedback = state["user_feedback"]

    prompt = f"""
    You are a professional YouTube thumbnail designer. Take this original thumbnail prompt and create an enhanced version that incorporates the user's specific feedback.

    ORIGINAL PROMPT:
    {chosen_prompt}

    USER FEEDBACK TO INCORPORATE:
    {user_feedback}

    Create an enhanced prompt that:
        1. Maintains the core concept from the original prompt
        2. Specifically addresses and implements the user's feedback requests
        3. Adds professional YouTube thumbnail specifications:
            - High contrast and bold visual elements
            - Clear focal points that draw the eye
            - Professional lighting and composition
            - Optimal text placement and readability with generous padding from edges
            - Colors that pop and grab attention
            - Elements that work well at small thumbnail sizes
            - IMPORTANT: Always ensure adequate white space/padding between any text and the image borders
    """

    response = llm.invoke(prompt)

    final_thumbnail_prompt = response.content

    client = OpenAI()

    result = client.images.generate(
        model="gpt-image-1",
        prompt=final_thumbnail_prompt,
        quality="high",
        moderation="low",
        size="auto",
    )

    image_bytes = base64.b64decode(result.data[0].b64_json)

    with open("thumbnail_final.jpg", "wb") as file:
        file.write(image_bytes)

# %%
graph_builder = StateGraph(State)

graph_builder.add_node("extract_audio", extract_audio)
graph_builder.add_node("transcribe_audio", transcribe_audio)
graph_builder.add_node("summarize_chunk", summarize_chunk)
graph_builder.add_node("mega_summary", mega_summary)
graph_builder.add_node("generate_thumbnails", generate_thumbnails)
graph_builder.add_node("human_feedback", human_feedback)
graph_builder.add_node("generate_hd_thumbnail", generate_hd_thumbnail)

graph_builder.add_edge(START, "extract_audio")
graph_builder.add_edge("extract_audio", "transcribe_audio")
graph_builder.add_conditional_edges(
    "transcribe_audio", dispatch_summarizers, ["summarize_chunk"]
)
graph_builder.add_edge("summarize_chunk", "mega_summary")
graph_builder.add_conditional_edges(
    "mega_summary", dispatch_artists, ["generate_thumbnails"]
)
graph_builder.add_edge("generate_thumbnails", "human_feedback")
graph_builder.add_edge("human_feedback", "generate_hd_thumbnail")
graph_builder.add_edge("generate_hd_thumbnail", END)

graph = graph_builder.compile(checkpointer=memory)

# %%
config = {
    "configurable": {
        "thread_id": "1",
    },
}

# %%
graph.invoke(
    {"video_file": "video.mp4"},
    config=config,
)
# Out:
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1.1_2 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x11f805160] Unknown cover type: 0x1.
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     creation_time   : 2026-01-02T13:13:21.000000Z
#   Duration: 00:00:11.07, start: 0.000000, bitrate: 12035 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1080x1920, 11833 kb/s, 30 fps, 30 tbr, 600 tbn (default)
#       Metadata:
#         creation_time   : 2026-01-02T13:13:21.000000Z
#         handler_name    : Core Media Video
#         vendor_id       : [0][0][0][0]
#         encoder         : H.264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 194 kb/s (default)
#       Metadata:
#         creation_time   : 2026-01-02T13:13:21.000000Z
#         handler_name    : Core Media Audio
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'video.mp3':
#   Metadata:
#     major_brand     : qt
#     minor_version   : 0
#     compatible_brands: qt
#     TSSE            : Lavf61.7.100
#   Stream #0:0(und): Audio: mp3, 44100 Hz, stereo, fltp (default)
#       Metadata:
#         creation_time   : 2026-01-02T13:13:21.000000Z
#         handler_name    : Core Media Audio
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libmp3lame
# [out#0/mp3 @ 0x11fe0dd90] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.383038%
# size=      87KiB time=00:00:05.52 bitrate= 129.3kbits/s speed=79.8x
# {'video_file': 'video.mp4',
#  'audio_file': 'video.mp3',
#  'transcription': '이제 저희 실생수는 이손잡이로 편하게 따라요. 물 따를 때도 편리하고 무거워서 물리는 일도 없어요. 거름망도 있어서 보리알갱이만 있으면 끝이 필요없이 보리차까지 만들어줘서 추천해요.\n',
#  'summaries': ['[Chunk 1] 저희 실생수는 편리한 손잡이로 쉽게 사용할 수 있으며, 물 따르기에도 편하고 무겁지 않아 안전합니다. 거름망이 있어 보리차를 쉽게 만들 수 있어 추천합니다.',
#   '[Chunk 1] 저희 실생수는 이손잡이로 사용이 편리하고, 물 따를 때 무거워서 물이 쏟아지지 않습니다. 거름망이 있어 보리알갱이를 사용하면 보리차도 쉽게 만들 수 있어 추천합니다.',
#   '[Chunk 1] 이 실생수는 이손잡이로 사용이 편리하고, 무거워서 물이 쏟아지는 일이 없으며, 거름망이 있어서 보리차를 쉽게 만들 수 있어 추천합니다.'],
#  'thumbnail_prompts': ['### YouTube Thumbnail Visual Prompt\n\n#### Main Visual Elements:\n1. **Central Image**: A clear, close-up shot of the practical water dispenser. The dispenser should be depicted at an angle that showcases its convenient handle and lightweight design. Include the filter prominently in the shot, perhaps even showing some barley tea brewing inside the dispenser.\n  \n2. **Background**: A bright, refreshing background that implies cleanliness and hydration. Consider using images of water droplets or a splash of water to evoke freshness. The background should not overpower the main product but should enhance its appeal.\n\n3. **Additional Elements**: Incorporate barley grains or a steaming cup of brewed barley tea next to the dispenser to visually reinforce the product’s intended use.\n\n#### Color Scheme:\n- **Dominant Colors**: Soft blues and greens to convey freshness and hydration.\n- **Accent Colors**: Use contrasting colors like light orange or gold to highlight the barley tea aspect and make the text stand out.\n- **Background Tone**: A light, airy gradient that transitions from white to pale blue to create depth without distraction.\n\n#### Text Overlay Suggestions (Korean Text):\n1. Main Text: “간편한 물통!” (Translation: "Convenient Water Dispenser!")\n   - Font Style: Bold, modern sans-serif to ensure readability.\n   - Color: White or light yellow with a drop shadow to make it pop against the background.\n\n2. Subtext: “보리차를 쉽게!” (Translation: "Brew Barley Tea Easily!")\n   - Font Style: A slightly smaller cursive or italic sans-serif for contrast.\n   - Color: Dark blue or orange to complement the main text.\n\n#### Overall Composition:\n- Position the water dispenser slightly off-center (to the right) to create a dynamic layout.\n- Place the main text (“간편한 물통!”) in the upper left corner, ensuring it doesn’t cover the main visual of the dispenser.\n- The subtext (“보리차를 쉽게!”) should be placed below the main text in a smaller font, aligned to the left, creating a visual hierarchy.\n- Add a soft shadow behind the dispenser to give it depth and make it stand out against the background.\n- Consider placing a border around the thumbnail in a light color (perhaps white or a subtle yellow) to enhance visibility on YouTube’s interface.\n\nThis visually attractive thumbnail with its engaging design and clear messaging should effectively draw viewers\' attention and encourage clicks!',
#   '### YouTube Thumbnail Visual Prompt\n\n**Main Visual Elements:**\n1. **Central Image of the Water Dispenser:**\n   - An eye-catching, high-quality image of the water dispenser in use. Show it being poured, with water flowing from the spout into a clear, styled glass. The dispenser should prominently feature the convenient handle and filter.\n  \n2. **Background Elements:**\n   - A light, refreshing background that suggests cleanliness and hydration. Consider using a blurred kitchen or outdoor setting that evokes a sense of freshness.\n   - Subtle illustrations or icons of barley grains or tea leaves in one corner, representing the filtering aspect of the product.\n\n3. **Additional Visual Elements:**\n   - Include a small badge or circular icon that says "Best Seller!" or "Recommended!" to create a sense of trust and urgency.\n\n**Color Scheme:**\n- **Primary Colors:** Use shades of light blue and white for a clean, refreshing feel. Light green accents to represent nature and the barley tea aspect.\n- **Contrast Colors:** Bright orange or yellow for the badge/icon to attract attention.\n  \n**Text Overlay Suggestions (Korean Text):**\n- Main Title: "가볍고 편리한 물 디스펜서!" (Lightweight and Convenient Water Dispenser!)\n- Subtitle: "보리차 준비가 간편해요!" (Easy to Brew Barley Tea!)\n- Use bold, easy-to-read fonts with a slight drop shadow for clear visibility.\n\n**Overall Composition:**\n- Position the water dispenser centrally to make it the focal point. \n- Place the title text at the top of the thumbnail to draw the viewer\'s attention immediately, slightly arched or in a horizontal banner.\n- Position the subtitle at the bottom, ensuring it’s legible against the background.\n- Balance the layout by placing the badge/icon in an upper corner, enhancing viewer focus without distracting from the main elements.\n- Ensure that the entire design is vibrant and appealing, with balanced spacing and emphasis on key components. Use a subtle gradient in the background to add depth without clutter.',
#   '### YouTube Thumbnail Visual Prompt\n\n#### Main Visual Elements:\n- **Central Image**: A sleek and modern water dispenser prominently displayed in the center of the thumbnail. The dispenser should have a clear body to showcase the filtered water and barley tea inside, with a bright handle that stands out visually.\n- **Brewed Barley Tea**: A glass or cup filled with brewed barley tea next to the dispenser, demonstrating its functionality. The tea should have a warm golden-brown color to indicate freshness.\n- **Key Feature Highlight**: An arrow or badge pointing to the dispenser’s handle, emphasizing the ease of use.\n  \n#### Color Scheme:\n- **Background**: A split background with a gradient – one side in a calming light blue (symbolizing water) and the other in a soft beige (reflecting barley tea).\n- **Text Colors**: Contrasting colors for text – white or bright yellow for high visibility on the blue side, and dark brown or black on the beige side.\n- **Accents**: Use vibrant colors like green (for freshness) and orange (for warmth) for additional elements like arrows or badges.\n\n#### Text Overlay Suggestions (Korean Text):\n- Main Text: "편리한 물 디스펜서!" (Convenient Water Dispenser!)\n- Subtext: "보리차를 쉽게 우려내세요!" (Easily Brew Barley Tea!)\n- Use bold, eye-catching fonts that are readable even on small screens. Consider adding a slight shadow to help the text pop against the background.\n\n#### Overall Composition:\n- The water dispenser should be the focal point, placed slightly off-center to the right. \n- Position the brewed barley tea cup to the left to balance the composition while also leading the viewer\'s eye toward the central element.\n- Place the main text above the central image, arched slightly for dynamic appeal. \n- Put the subtext beneath the central image, smaller but still bold, providing additional context.\n- Ensure that there is a reasonable amount of negative space around the edges to prevent a cluttered appearance, making the thumbnail look clean and professional.\n\n#### Additional Elements:\n- Optionally, include a small logo in one corner (brand or channel logo) to establish brand identity.\n- Consider a visual cue (like a starburst or checkmark) near the handle to emphasize the “easy use” feature, adding an element of intrigue and excitement about the product.\n\nThis composition will create an attractive, engaging thumbnail that encourages viewers to click and learn more about this practical water dispenser.',
#   "**YouTube Thumbnail Detailed Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Product Image**: A high-resolution image of the lightweight water dispenser with a prominent handle, showcasing its ergonomic design. Position the dispenser slightly to the right of the thumbnail for dynamic balance.\n2. **Brewed Barley Tea**: To the left of the water dispenser, display a clear glass of brewed barley tea with some barley grains scattered around or elegantly placed beside the glass, highlighting the filter feature.\n3. **User Interaction**: Include a hand positioned near the dispenser handle in a pouring motion to convey ease of use. This can be semi-transparent or blended to not distract from the product focus.\n\n**Color Scheme:**\n- **Background Color**: A soft, gradient blue to green background to evoke a sense of freshness and hydration, reminiscent of water.\n- **Accent Colors**: Use yellow or gold accents for the barley tea elements, giving a warm inviting look, and white for any textual features, ensuring legibility.\n- **Product Color**: The water dispenser itself should be depicted in a sleek, modern color (such as white or light gray) to convey a clean and safe aesthetic.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Top Text: “가벼운 물 디스펜서” (Lightweight Water Dispenser) in bold, attractive font. Consider using a vibrant white or yellow to stand out against the background.\n2. Bottom Text: “쉽고 안전하게 차 만들기” (Easy and Safe Tea Brewing) in a slightly smaller font. Use a contrasting color (perhaps dark gray or blue) for differentiation.\n\n**Overall Composition:**\n- The layout should have the product on the right side, a full glass of barley tea on the left, and the text overlay split across the top and bottom without overlapping with the images. \n- Ensure ample white space around the images so the viewer’s eyes are naturally drawn to the key visuals and the compelling text.\n- Use a slightly blurred background if needed to bring the product and text into sharper focus, enhancing the overall professional and attractive look of the thumbnail. \n\nThis composition will aim to attract viewers by clearly conveying the product's practicality and the enjoyable experience of using it to brew barley tea.",
#   '### YouTube Thumbnail Visual Prompt\n\n**Main Visual Elements:**\n1. **Central Product Image:** A clear, high-quality image of the water dispenser prominently displayed in the center. It should highlight the unique features such as the convenient handle and the filter mechanism. The dispenser can be filled with water and have a few barley tea leaves floating inside to visually indicate its brewing capability.\n   \n2. **Background Elements:** Soft, blurred images of fresh barley or barley tea in a glass to emphasize the product\'s purpose. This can create a context that relates to brewing. Optionally, add subtle sparkles around the dispenser to suggest freshness and cleanliness.\n\n3. **User Interaction:** A hand (diverse representation, perhaps a female hand) reaching for the dispenser, showcasing the ease of use and lightweight nature. This can help viewers visualize the practical application of the product.\n\n**Color Scheme:**\n- **Dominant Colors:** Soft blues and greens to convey a sense of calmness and freshness, highlighting the water theme.\n- **Accent Colors:** Light brown or beige for the barley elements, adding a warm touch that relates to the natural aspect of barley tea. Use white for the product and hand to make them stand out against the background.\n- **Contrast Elements:** A touch of yellow or gold to highlight the text overlay for better visibility and attract the viewer\'s eye.\n\n**Text Overlay Suggestions (Korean Text):**\n1. **Main Title:** "편리한 물 디스펜서!" (Practical Water Dispenser!)\n   - Font: Bold and modern, easy to read, preferably a sans-serif style.\n   - Color: Bright yellow with a dark outline for contrast against the background.\n   \n2. **Subheading:** "보리차도 간편하게!" (Brew Barley Tea Easily!)\n   - Font: Slightly smaller, but still bold; could be in an italic style to suggest movement.\n   - Color: White or light beige, possibly with a drop shadow for depth.\n\n**Overall Composition:**\n- **Layout:** The central product image should take up about 50-60% of the thumbnail space, with the text overlay placed at the top and bottom, ensuring that neither obstructs the product image.\n- **Balancing elements:** Ensure the hand and background elements frame the product without overcrowding it. The background should be a gradient that complements the main colors but does not distract from the main product.\n- **Call-to-Action Element:** A small badge with the text "구매 링크 아래!" (Link Below to Purchase!) in a corner, using a contrasting color like bright orange, to prompt viewers to take action.\n\nThis composition will engage viewers by clearly highlighting the product benefits while maintaining an appealing aesthetic that invites curiosity.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Background:** A soft, blurred image of a bright and inviting kitchen setting, with a hint of sunlight filtering in to create a warm atmosphere.\n2. **Main Product:** A prominently displayed, high-quality image of the 실생수 (water pitcher) in use. The pitcher should be filled with a refreshing beverage, perhaps a light-colored barley tea, with a delicate steam rising from it.\n3. **Highlight Feature:** A close-up inset of the built-in strainer (거름망) that showcases its functionality. This can be placed on one corner of the thumbnail.\n4. **Action Element:** An animated visual of water being poured from the pitcher into a beautiful glass, emphasizing the convenience and ease of use.\n\n**Color Scheme:**\n- **Primary Colors:** Soft shades of blue and green to evoke a sense of calm and freshness, complemented by neutral backgrounds (whites and soft grays) to allow the product to pop.\n- **Accent Colors:** Use warm yellows or light browns to highlight the barley tea in the pitcher, creating contrast with the cooler tones.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Large, bold text at the top: "편리한 손잡이!" (Convenient Handle!)\n2. Medium-sized text at the bottom: "거름망으로 더 맛있게!" (Brew It Deliciously with the Strainer!)\n3. Use a playful font to convey friendliness and approachability, ensuring legibility against the background.\n\n**Overall Composition:**\n- Position the water pitcher slightly off-center to draw the viewer\'s eye, with the text placed strategically around it without overcrowding the image.\n- The background should remain subtle but inviting, ensuring that the focus stays on the product.\n- Use a slight shadow effect on the text to make it stand out against the background and maintain readability.\n- Visual balance is essential, so avoid cluttering the thumbnail with too many elements—focus on showcasing the main features of the product invitingly and engagingly.\n\nThis visually appealing and informative thumbnail will attract viewers\' attention and effectively communicate the benefits of using the 실생수 for making delicious barley tea.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Image:** A visually appealing close-up shot of the 실생수 (filtering water pitcher), showcasing its ergonomic handle and lightweight design. The pitcher should be filled with clear water, with a few floating barley grains to highlight its use for brewing 보리차 (barley tea).\n  \n2. **Background Elements:** A kitchen countertop background with a hint of greenery (such as a potted plant or herbs) to create a homey and fresh atmosphere. A steaming cup of 보리차 should be in the foreground, with a small stack of barley grains to the side.\n\n3. **Accessories:** Include an artistic representation of the filter inside the pitcher, showing how it effectively filters the barley grains.\n\n**Color Scheme:**\n- **Primary Colors:** Soft greens and warm browns to evoke a sense of nature and health.\n- **Accent Colors:** Light blues and whites for a clean and refreshing look, resembling water.\n- **Text Color:** Bright contrasting colors for text overlay, like white or yellow with a slight shadow for better visibility against the background.\n\n**Text Overlay Suggestions (in Korean):**\n1. **Main Title:** "편리하고 안전한 실생수!" (Convenient and Safe Filtering Water!)\n2. **Subtitle:** "보리차 만들기 꿀팁" (Tips for Making Barley Tea)\n\n**Overall Composition:**\n- The **pitcher** should be centered, slightly tilted to show off its features. \n- The **cup of 보리차** should be positioned on one side, slightly overlapping with the pitcher to create depth.\n- **Text overlays** should be strategically placed at the top and bottom, ensuring they do not obscure the main visuals. The main title can be at the top with a larger font, while the subtitle can be smaller but bold at the bottom.\n- Consider adding a glowing or shadow effect around the pitcher to make it stand out even more.\n  \nThis composition should attract viewers by highlighting the practicality and innovative features of the 실생수 while also visually representing the delightful experience of making and enjoying 보리차.',
#   "**YouTube Thumbnail Visual Prompt:**\n\n**Main Visual Elements:**\n1. **Central Image:** A high-quality image of the 실생수 (a specific type of water pot) prominently placed in the center. The pot should be shown filled with barley tea, with steam rising gently from the surface to suggest warmth and freshness. \n2. **Background:** A blurred kitchen or tea-making environment to create a cozy, homely atmosphere, with soft highlights that suggest natural light. Incorporate hints of barley grains scattered around the background to visually connect with the topic.\n3. **Floating Textures:** Include subtle, semi-transparent graphic elements like barley grains or tea leaves near the edges of the thumbnail to enrich the visual context.\n\n**Color Scheme:**\n- **Primary Colors:** Warm earthy tones (light beige, soft browns) to evoke a natural and organic feel. \n- **Accent Colors:** Splashes of green (to suggest freshness) and light amber (to represent the color of brewed tea).\n- **Text Color:** Use contrasting colors for the text, such as deep brown or dark green against the warm background to ensure readability.\n\n**Text Overlay Suggestions (in Korean):**\n1. Main Title Text: “저희 실생수와 보리차의 비밀!” (The Secret of Our 실생수 and Barley Tea!)\n   - Suggested Font: Bold, playful font that is easy to read with a slight curvature to suggest warmth and friendliness.\n   - Placement: Positioned near the top to ensure it catches attention first.\n  \n2. Subtitle Text: “쉽고 안전한 보리차 만들기” (Easy and Safe Barley Tea Making)\n   - Suggested Font: Slightly smaller, simple sans-serif font for clarity.\n   - Placement: Just below the main title, creating a visual hierarchy.\n\n**Overall Composition:**\n- The central image should dominate the visual space, with text overlay strategically placed to avoid obscuring key visual elements.\n- Create a balanced composition by ensuring that the text does not compete with the visual elements but instead complements them.\n- Use drop shadows or outlines on the text to enhance visibility against the background.\n- Ensure a slight vignette effect around the edges to draw the viewer's focus toward the center of the thumbnail.\n\nThis combination of visual elements, colors, and carefully crafted text is designed to attract viewers, conveying both the essence of the product and the inviting experience of making barley tea.",
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n- A large, eye-catching image of the 실생수 (filtering water pitcher) prominently displayed in the center. It should be shown in an appealing angle that highlights its convenient handle and the built-in filter.\n- Include a close-up illustration or real-life photo of the barley grains (보리알갱이) next to the pitcher to emphasize its feature for making barley tea (보리차).\n- Add a steaming, fresh cup of barley tea next to the pitcher to showcase the end product the audience can expect.\n- Optional: A light, blurred background of a cozy kitchen setting to convey a homey feeling or a nature-oriented backdrop to associate with the healthy aspect of the barley tea.\n\n**Color Scheme:**\n- Use warm, inviting colors like soft browns, yellows, and earthy greens to create a sense of comfort and health.\n- Add splashes of white and light blue to enhance the visual appeal and make the image feel fresh and clean.\n\n**Text Overlay Suggestions (Korean Text):**\n- Main text: "편리한 물따르기!" (Convenient Water Pouring!)\n  - Font: Bold and modern, easy to read, placed at the top of the thumbnail.\n- Additional text: "보리차 만들기 꿀팁!" (Barley Tea Making Tips!)\n  - Font: Slightly smaller, complementary style, placed at the bottom or sides to balance the composition.\n\n**Overall Composition:**\n- The pitcher should be the focal point, occupying the central area of the thumbnail.\n- Balance the layout by placing the related images (barley grains and tea cup) on either side of the main product to create symmetry.\n- Text should be strategically positioned to ensure it stands out without obstructing the visuals of the products.\n- Utilize a drop shadow or outline effect for the text to enhance legibility against the background.\n- Overall, the composition should be vibrant, engaging, and informative to draw viewers\' attention quickly and encourage clicks.',
#   "### YouTube Thumbnail Visual Prompt\n\n#### Main Visual Elements:\n1. **Central Image**: A well-designed, modern water-filling jug featuring an ergonomic handle and a mesh strainer prominently displayed. The jug should look user-friendly and appealing, positioned slightly tilted to showcase the strainer with barley grains spilling out or around it.\n   \n2. **Background**: A blurred kitchen countertop setting to create a warm and inviting atmosphere. A soft-focus kettle and herbal plants can be included subtly in the background to emphasize a natural theme.\n\n3. **Highlight Details**: Illustrate droplets of water flowing smoothly from the jug’s spout, emphasizing the ease of pouring. A subtle glow or sparkle effect around the jug can add visual appeal.\n\n#### Color Scheme:\n- **Primary Colors**: Soft pastel shades like mint green and sky blue for a fresh and clean look.\n- **Accent Colors**: Use warm yellows and earthy browns for barley and complement the background, creating a contrast that catches the eye.\n- **Text Colors**: Bold white or dark green text to stand out against the background.\n\n#### Text Overlay Suggestions (Korean Text):\n- Top Text: “편리한 물 따르기!” (Convenient Water Pouring!)\n- Bottom Text: “거름망으로 쉽게 보리차 만들기” (Easily Make Barley Tea with Strainer)\n\n#### Overall Composition:\n- Place the central image of the water jug slightly off-center (to the left).\n- The top text should arch over the jug, ensuring it doesn’t obstruct the view of the main visual.\n- The bottom text can be placed on the lower right corner in a balanced manner, ensuring it’s clear and readable.\n- Consider using a slight drop shadow on the text for better visibility against the background.\n- Add a subtle border or frame that complements the color scheme, enhancing overall attractiveness without being too distracting. \n\nThis combination of elements will create an eye-catching thumbnail that effectively conveys the product's appeal and encourages viewers to click and learn more.",
#   '**YouTube Thumbnail Visual Prompt for "실생수"**\n\n**Main Visual Elements:**\n1. **Product Showcase:** Place a high-quality image of the "실생수" product prominently in the center. The product should be depicted in an attractive angle that highlights its convenient handles and strainer feature. \n2. **Action Shot:** Incorporate an additional image of someone effortlessly pouring from the product, showcasing the ease of use and preventing spills. This could be a hand with the product and a cup just below it.\n3. **Background:** Use a light kitchen or beverage preparation background that suggests an inviting environment, perhaps with barley tea ingredients (e.g., barley grains or tea leaves) to reinforce the product\'s purpose.\n\n**Color Scheme:**\n- Utilize a warm and inviting color palette with soft earthy tones such as beige, light brown, and pale green to represent natural ingredients like barley.\n- Add pops of brighter colors (e.g., saturated yellows or greens) for the text overlay to ensure it stands out against the softer background.\n- Incorporate a subtle gradient behind the product, transitioning from light beige to white for a clean, professional look.\n\n**Text Overlay Suggestions (Korean Text):**\n1. **Top Section:** "완벽한 차 만들기!" (Perfect Tea Making!) - Bold and eye-catching font, potentially in a bright yellow or white with a slight shadow to enhance readability.\n2. **Bottom Section:** "실생수의 편리함" (Convenience of 실생수) - Use a slightly smaller font size in a contrasting color, perhaps dark green or navy blue, ensuring it complements the primary text but remains readable.\n\n**Overall Composition:**\n- Position the product image slightly off-center to the right to create a dynamic flow, with the action shot (pouring tea) on the left, leading the viewer’s eye toward the product.\n- Text elements should be placed strategically at the top and bottom to balance the composition without overcrowding the image. The top text should be larger to capture attention first, while the bottom text reinforces the message of convenience.\n- Ensure ample whitespace around the edges of the thumbnail to avoid a cluttered appearance, focusing the viewer\'s attention on the key elements (product, action, and text).\n\nThis detailed visual prompt will help create an engaging and attractive thumbnail that promotes the usability and efficiency of "실생수" and catches the attention of potential viewers on YouTube.',
#   '### YouTube Thumbnail Visual Prompt for "실생수"\n\n#### Main Visual Elements:\n1. **Product Showcase**: The central focus should be a high-quality image of the "실생수" product, prominently displaying the convenient handles and built-in strainer. The product should be shown in a dynamic angle to highlight its usability and design.\n  \n2. **Background Scene**: Create a soft-focus kitchen setting in the background to convey an atmosphere of warmth and usability. You could suggest elements such as a wooden table, a kettle, and barley grains to reinforce the tea-making theme.\n\n3. **User Interaction**: Include an illustrated hand or silhouette using the product (pouring tea into a cup) to emphasize the ease of use and functionality.\n\n#### Color Scheme:\n- **Primary Colors**: Use warm earthy tones like beige, light brown, and soft greens to evoke a sense of comfort and connection to nature. These colors will also complement the barley tea theme.\n- **Accent Colors**: Utilize brighter colors such as yellow for highlights and text elements, creating contrast and drawing the viewer\'s eyes to key details.\n\n#### Text Overlay Suggestions (Korean Text):\n1. **Main Title**: \n   - "편리한 수조!" (Convenient Water Container!)\n   - Use a bold font, white letters with a slight shadow for readability against the background.\n\n2. **Subtitle**: \n   - "쉽고 빠른 보리차!" (Easy & Quick Barley Tea!)\n   - Place this below the main title in a smaller font size, possibly in a warmer hue like soft yellow or green to stand out but not overshadow the main title.\n\n#### Overall Composition:\n- Position the product slightly off-center to the right to create a dynamic composition while leaving space on the left for the text. \n- The background should have a depth of field effect, making the product the focal point while softly indicating the theme of the kitchen.\n- The text should be easily readable, with no clutter around it, ensuring that viewers can immediately grasp the message.\n- Consider adding a small logo or icon in one corner to enhance brand recognition without detracting from the product display.\n\nBy combining these visual elements thoughtfully, the thumbnail will attract viewers by highlighting both the product\'s functionality and the enjoyable experience of making barley tea.',
#   '**YouTube Thumbnail Visual Prompt for "실생수" Product**\n\n**Main Visual Elements:**\n1. **Product Focus:** A clear, high-resolution image of the "실생수" product, prominently displayed in the center. The product should be slightly angled to showcase its convenient handles and integrated strainer.\n2. **Barley Tea Elements:** Include an overflowing cup of barley tea beside the product, with a few tea leaves scattered around to signify freshness. The steam rising from the cup should be visible, suggesting warmth and inviting viewers in.\n3. **Background Elements:** Subtle images of a kitchen setting in the background, with soft, blurred edges, creating a cozy atmosphere without distracting from the main product. \n\n**Color Scheme:**\n- **Primary Colors:** Soft pastel colors like mint green and light beige to suggest freshness and warmth.\n- **Accent Colors:** Rich brown tones representing barley tea, providing contrast and drawing attention to the beverage.\n- **Text Color:** Vibrant white or light yellow for the text overlay, ensuring it stands out against the background.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Main Headline: "편리함과 효율성!" (Convenience and Efficiency!) \n   - Positioned at the top of the thumbnail in bold, eye-catching font.\n2. Subheading: "완벽한 보리차 준비!" (Perfect Barley Tea Preparation!)\n   - Placed below the main headline in slightly smaller font, perhaps in a cursive or softer style for a friendly appeal.\n\n**Overall Composition:**\n- The product image should be centered with the cup of barley tea to the right of it, creating a balanced look. \n- The text should be layered in a way that it does not obstruct the view of the product but instead enhances its appeal.\n- The overall layout should maintain a clean, uncluttered feel, with enough white space around the edges to keep the viewer\'s focus on the **"실생수"** product and the accompanying graphics.\n- Consider adding a subtle drop shadow effect to the product and text to give them depth and make them pop out from the background. \n\nThis carefully designed thumbnail will attract viewers by emphasizing the practicality of the "실생수" while inviting them to explore its benefits in beverage preparation.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Product Image:** Place a high-quality image of the "실생수" product prominently in the center. The product should be shown with its handles visible, highlighting its ergonomic design. Include the strainer element, maybe placed beside or slightly behind the main product to indicate its functionality.\n   \n2. **Contextual Background:** Use a blurred background that depicts a kitchen setting or a cozy tea-drinking environment. This adds context and makes the thumbnail relatable. You could include a steaming cup of barley tea to signify the product\'s primary use.\n\n3. **Action Visuals:** Include a hand reaching to pour from the product, emphasizing its easy-to-use features. Additionally, add small visual effects such as splashes to convey movement and action, making it appear as though the pouring is smooth and spill-proof.\n\n**Color Scheme:**\n- **Warm Colors:** Use a warm and inviting color palette that includes shades of soft browns, creams, and light greens to evoke feelings of comfort and homeliness. \n- **Accent Colors:** Include light accents of gold or bright teal to make the thumbnail pop and draw attention to specific areas, particularly around the product and text overlays.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Title: "편리한 사용성!" (Convenient Usability!)\n2. Subtitle: "완벽한 보리차 준비!" (Perfect Barley Tea Preparation!)\n3. Optional Call to Action: "지금 확인하세요!" (Check It Out Now!)\n\n**Overall Composition:**\n- Arrange the product centrally, with primary text (the title) at the top in a bold, easy-to-read font (white or yellow with a dark shadow for contrast). Place the subtitle below it in a slightly smaller font.\n- Use the bottom area for the call-to-action, employing a contrasting banner or bright background stripe to make it stand out.\n- Ensure that there’s a balanced flow where viewers’ eyes move from the product to the text seamlessly.\n- Leave some negative space around text areas for clarity and emphasis, reducing visual clutter and enhancing overall readability.\n\nThis composition not only highlights the product\'s usability but also creates an inviting atmosphere, enticing viewers to click on the video for more information.',
#   '**YouTube Thumbnail Visual Prompt:**\n\n**Main Visual Elements:**\n1. **Product Focus**: Showcase the "실생수" product prominently in the center, highlighting its handles and strainer. Arrange the product at an angle to create depth.\n2. **Background**: Use a softly blurred kitchen setting to emphasize a lifestyle aspect, indicating that the product is practical for everyday use.\n3. **Beverage Visual**: To the side of the product, include a clear glass of freshly made barley tea, possibly with ice and a slice of lemon, to demonstrate the end-use of the product. \n\n**Color Scheme:**\n- Use a warm and inviting color palette. \n  - **Main colors**: Soft greens and browns (reflecting barley tea and natural materials).\n  - **Accent colors**: Light cream or beige for background to create contrast and make the product pop.\n  - **Text colors**: Utilize a combination of bold dark green and vibrant yellow to draw attention to text overlays and ensure readability.\n\n**Text Overlay Suggestions (Korean Text):**\n- Main Text: "쉽고 편리한 사용!" (Easy and Convenient to Use!)\n  - Font: Bold and modern sans-serif for impact, colored in dark green.\n- Subtext: "완벽한 보리차 만들기" (Perfect for Making Barley Tea)\n  - Font: Italicized or lighter weight sans-serif, colored in a contrasting yellow to complement the main text.\n\n**Overall Composition:**\n- Ensure the thumbnail is not overcrowded; the product should be the focal point with clear viewing angles.\n- Place the main text at the top of the thumbnail in a large font, keeping it concise and engaging.\n- Position the subtext towards the bottom of the image to provide additional information without overshadowing the main message.\n- Include a small call-to-action overlay, such as a "Watch Now!" badge in a corner, colored in a bright contrasting color (like red or bright orange) for emphasis.\n- The overall look should convey a sense of warmth, functionality, and trust, inviting viewers to learn more about this convenient product.'],
#  'thumbnail_sketches': ['thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg',
#   'thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg',
#   'thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg'],
#  'final_summary': 'The summaries collectively highlight the features of a product called "실생수." It is designed for easy use thanks to its convenient handles, making it suitable for pouring without the risk of spills due to its weight. Additionally, the product includes a strainer, which facilitates the preparation of barley tea. Overall, it is highly recommended for its usability and efficiency in making beverages.',
#  '__interrupt__': [Interrupt(value={'chosen_thumbnail': 'Which thumbnail do you like the most?', 'feedback': "Provide any feedback or changes you'd like for the final thumbnail."}, id='b751d69d9c85dbf88364f4a52cf95165')]}

# %%
response = {
    "user_feedback": "Give it a more vibrant color palette and make the text more accurate.",
    "chosen_prompt": 2,
}

graph.invoke(
    Command(resume=response),
    config=config,
)
# Out:
# {'video_file': 'video.mp4',
#  'audio_file': 'video.mp3',
#  'transcription': '이제 저희 실생수는 이손잡이로 편하게 따라요. 물 따를 때도 편리하고 무거워서 물리는 일도 없어요. 거름망도 있어서 보리알갱이만 있으면 끝이 필요없이 보리차까지 만들어줘서 추천해요.\n',
#  'summaries': ['[Chunk 1] 저희 실생수는 편리한 손잡이로 쉽게 사용할 수 있으며, 물 따르기에도 편하고 무겁지 않아 안전합니다. 거름망이 있어 보리차를 쉽게 만들 수 있어 추천합니다.',
#   '[Chunk 1] 저희 실생수는 이손잡이로 사용이 편리하고, 물 따를 때 무거워서 물이 쏟아지지 않습니다. 거름망이 있어 보리알갱이를 사용하면 보리차도 쉽게 만들 수 있어 추천합니다.',
#   '[Chunk 1] 이 실생수는 이손잡이로 사용이 편리하고, 무거워서 물이 쏟아지는 일이 없으며, 거름망이 있어서 보리차를 쉽게 만들 수 있어 추천합니다.'],
#  'thumbnail_prompts': ['### YouTube Thumbnail Visual Prompt\n\n#### Main Visual Elements:\n1. **Central Image**: A clear, close-up shot of the practical water dispenser. The dispenser should be depicted at an angle that showcases its convenient handle and lightweight design. Include the filter prominently in the shot, perhaps even showing some barley tea brewing inside the dispenser.\n  \n2. **Background**: A bright, refreshing background that implies cleanliness and hydration. Consider using images of water droplets or a splash of water to evoke freshness. The background should not overpower the main product but should enhance its appeal.\n\n3. **Additional Elements**: Incorporate barley grains or a steaming cup of brewed barley tea next to the dispenser to visually reinforce the product’s intended use.\n\n#### Color Scheme:\n- **Dominant Colors**: Soft blues and greens to convey freshness and hydration.\n- **Accent Colors**: Use contrasting colors like light orange or gold to highlight the barley tea aspect and make the text stand out.\n- **Background Tone**: A light, airy gradient that transitions from white to pale blue to create depth without distraction.\n\n#### Text Overlay Suggestions (Korean Text):\n1. Main Text: “간편한 물통!” (Translation: "Convenient Water Dispenser!")\n   - Font Style: Bold, modern sans-serif to ensure readability.\n   - Color: White or light yellow with a drop shadow to make it pop against the background.\n\n2. Subtext: “보리차를 쉽게!” (Translation: "Brew Barley Tea Easily!")\n   - Font Style: A slightly smaller cursive or italic sans-serif for contrast.\n   - Color: Dark blue or orange to complement the main text.\n\n#### Overall Composition:\n- Position the water dispenser slightly off-center (to the right) to create a dynamic layout.\n- Place the main text (“간편한 물통!”) in the upper left corner, ensuring it doesn’t cover the main visual of the dispenser.\n- The subtext (“보리차를 쉽게!”) should be placed below the main text in a smaller font, aligned to the left, creating a visual hierarchy.\n- Add a soft shadow behind the dispenser to give it depth and make it stand out against the background.\n- Consider placing a border around the thumbnail in a light color (perhaps white or a subtle yellow) to enhance visibility on YouTube’s interface.\n\nThis visually attractive thumbnail with its engaging design and clear messaging should effectively draw viewers\' attention and encourage clicks!',
#   '### YouTube Thumbnail Visual Prompt\n\n**Main Visual Elements:**\n1. **Central Image of the Water Dispenser:**\n   - An eye-catching, high-quality image of the water dispenser in use. Show it being poured, with water flowing from the spout into a clear, styled glass. The dispenser should prominently feature the convenient handle and filter.\n  \n2. **Background Elements:**\n   - A light, refreshing background that suggests cleanliness and hydration. Consider using a blurred kitchen or outdoor setting that evokes a sense of freshness.\n   - Subtle illustrations or icons of barley grains or tea leaves in one corner, representing the filtering aspect of the product.\n\n3. **Additional Visual Elements:**\n   - Include a small badge or circular icon that says "Best Seller!" or "Recommended!" to create a sense of trust and urgency.\n\n**Color Scheme:**\n- **Primary Colors:** Use shades of light blue and white for a clean, refreshing feel. Light green accents to represent nature and the barley tea aspect.\n- **Contrast Colors:** Bright orange or yellow for the badge/icon to attract attention.\n  \n**Text Overlay Suggestions (Korean Text):**\n- Main Title: "가볍고 편리한 물 디스펜서!" (Lightweight and Convenient Water Dispenser!)\n- Subtitle: "보리차 준비가 간편해요!" (Easy to Brew Barley Tea!)\n- Use bold, easy-to-read fonts with a slight drop shadow for clear visibility.\n\n**Overall Composition:**\n- Position the water dispenser centrally to make it the focal point. \n- Place the title text at the top of the thumbnail to draw the viewer\'s attention immediately, slightly arched or in a horizontal banner.\n- Position the subtitle at the bottom, ensuring it’s legible against the background.\n- Balance the layout by placing the badge/icon in an upper corner, enhancing viewer focus without distracting from the main elements.\n- Ensure that the entire design is vibrant and appealing, with balanced spacing and emphasis on key components. Use a subtle gradient in the background to add depth without clutter.',
#   '### YouTube Thumbnail Visual Prompt\n\n#### Main Visual Elements:\n- **Central Image**: A sleek and modern water dispenser prominently displayed in the center of the thumbnail. The dispenser should have a clear body to showcase the filtered water and barley tea inside, with a bright handle that stands out visually.\n- **Brewed Barley Tea**: A glass or cup filled with brewed barley tea next to the dispenser, demonstrating its functionality. The tea should have a warm golden-brown color to indicate freshness.\n- **Key Feature Highlight**: An arrow or badge pointing to the dispenser’s handle, emphasizing the ease of use.\n  \n#### Color Scheme:\n- **Background**: A split background with a gradient – one side in a calming light blue (symbolizing water) and the other in a soft beige (reflecting barley tea).\n- **Text Colors**: Contrasting colors for text – white or bright yellow for high visibility on the blue side, and dark brown or black on the beige side.\n- **Accents**: Use vibrant colors like green (for freshness) and orange (for warmth) for additional elements like arrows or badges.\n\n#### Text Overlay Suggestions (Korean Text):\n- Main Text: "편리한 물 디스펜서!" (Convenient Water Dispenser!)\n- Subtext: "보리차를 쉽게 우려내세요!" (Easily Brew Barley Tea!)\n- Use bold, eye-catching fonts that are readable even on small screens. Consider adding a slight shadow to help the text pop against the background.\n\n#### Overall Composition:\n- The water dispenser should be the focal point, placed slightly off-center to the right. \n- Position the brewed barley tea cup to the left to balance the composition while also leading the viewer\'s eye toward the central element.\n- Place the main text above the central image, arched slightly for dynamic appeal. \n- Put the subtext beneath the central image, smaller but still bold, providing additional context.\n- Ensure that there is a reasonable amount of negative space around the edges to prevent a cluttered appearance, making the thumbnail look clean and professional.\n\n#### Additional Elements:\n- Optionally, include a small logo in one corner (brand or channel logo) to establish brand identity.\n- Consider a visual cue (like a starburst or checkmark) near the handle to emphasize the “easy use” feature, adding an element of intrigue and excitement about the product.\n\nThis composition will create an attractive, engaging thumbnail that encourages viewers to click and learn more about this practical water dispenser.',
#   "**YouTube Thumbnail Detailed Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Product Image**: A high-resolution image of the lightweight water dispenser with a prominent handle, showcasing its ergonomic design. Position the dispenser slightly to the right of the thumbnail for dynamic balance.\n2. **Brewed Barley Tea**: To the left of the water dispenser, display a clear glass of brewed barley tea with some barley grains scattered around or elegantly placed beside the glass, highlighting the filter feature.\n3. **User Interaction**: Include a hand positioned near the dispenser handle in a pouring motion to convey ease of use. This can be semi-transparent or blended to not distract from the product focus.\n\n**Color Scheme:**\n- **Background Color**: A soft, gradient blue to green background to evoke a sense of freshness and hydration, reminiscent of water.\n- **Accent Colors**: Use yellow or gold accents for the barley tea elements, giving a warm inviting look, and white for any textual features, ensuring legibility.\n- **Product Color**: The water dispenser itself should be depicted in a sleek, modern color (such as white or light gray) to convey a clean and safe aesthetic.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Top Text: “가벼운 물 디스펜서” (Lightweight Water Dispenser) in bold, attractive font. Consider using a vibrant white or yellow to stand out against the background.\n2. Bottom Text: “쉽고 안전하게 차 만들기” (Easy and Safe Tea Brewing) in a slightly smaller font. Use a contrasting color (perhaps dark gray or blue) for differentiation.\n\n**Overall Composition:**\n- The layout should have the product on the right side, a full glass of barley tea on the left, and the text overlay split across the top and bottom without overlapping with the images. \n- Ensure ample white space around the images so the viewer’s eyes are naturally drawn to the key visuals and the compelling text.\n- Use a slightly blurred background if needed to bring the product and text into sharper focus, enhancing the overall professional and attractive look of the thumbnail. \n\nThis composition will aim to attract viewers by clearly conveying the product's practicality and the enjoyable experience of using it to brew barley tea.",
#   '### YouTube Thumbnail Visual Prompt\n\n**Main Visual Elements:**\n1. **Central Product Image:** A clear, high-quality image of the water dispenser prominently displayed in the center. It should highlight the unique features such as the convenient handle and the filter mechanism. The dispenser can be filled with water and have a few barley tea leaves floating inside to visually indicate its brewing capability.\n   \n2. **Background Elements:** Soft, blurred images of fresh barley or barley tea in a glass to emphasize the product\'s purpose. This can create a context that relates to brewing. Optionally, add subtle sparkles around the dispenser to suggest freshness and cleanliness.\n\n3. **User Interaction:** A hand (diverse representation, perhaps a female hand) reaching for the dispenser, showcasing the ease of use and lightweight nature. This can help viewers visualize the practical application of the product.\n\n**Color Scheme:**\n- **Dominant Colors:** Soft blues and greens to convey a sense of calmness and freshness, highlighting the water theme.\n- **Accent Colors:** Light brown or beige for the barley elements, adding a warm touch that relates to the natural aspect of barley tea. Use white for the product and hand to make them stand out against the background.\n- **Contrast Elements:** A touch of yellow or gold to highlight the text overlay for better visibility and attract the viewer\'s eye.\n\n**Text Overlay Suggestions (Korean Text):**\n1. **Main Title:** "편리한 물 디스펜서!" (Practical Water Dispenser!)\n   - Font: Bold and modern, easy to read, preferably a sans-serif style.\n   - Color: Bright yellow with a dark outline for contrast against the background.\n   \n2. **Subheading:** "보리차도 간편하게!" (Brew Barley Tea Easily!)\n   - Font: Slightly smaller, but still bold; could be in an italic style to suggest movement.\n   - Color: White or light beige, possibly with a drop shadow for depth.\n\n**Overall Composition:**\n- **Layout:** The central product image should take up about 50-60% of the thumbnail space, with the text overlay placed at the top and bottom, ensuring that neither obstructs the product image.\n- **Balancing elements:** Ensure the hand and background elements frame the product without overcrowding it. The background should be a gradient that complements the main colors but does not distract from the main product.\n- **Call-to-Action Element:** A small badge with the text "구매 링크 아래!" (Link Below to Purchase!) in a corner, using a contrasting color like bright orange, to prompt viewers to take action.\n\nThis composition will engage viewers by clearly highlighting the product benefits while maintaining an appealing aesthetic that invites curiosity.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Background:** A soft, blurred image of a bright and inviting kitchen setting, with a hint of sunlight filtering in to create a warm atmosphere.\n2. **Main Product:** A prominently displayed, high-quality image of the 실생수 (water pitcher) in use. The pitcher should be filled with a refreshing beverage, perhaps a light-colored barley tea, with a delicate steam rising from it.\n3. **Highlight Feature:** A close-up inset of the built-in strainer (거름망) that showcases its functionality. This can be placed on one corner of the thumbnail.\n4. **Action Element:** An animated visual of water being poured from the pitcher into a beautiful glass, emphasizing the convenience and ease of use.\n\n**Color Scheme:**\n- **Primary Colors:** Soft shades of blue and green to evoke a sense of calm and freshness, complemented by neutral backgrounds (whites and soft grays) to allow the product to pop.\n- **Accent Colors:** Use warm yellows or light browns to highlight the barley tea in the pitcher, creating contrast with the cooler tones.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Large, bold text at the top: "편리한 손잡이!" (Convenient Handle!)\n2. Medium-sized text at the bottom: "거름망으로 더 맛있게!" (Brew It Deliciously with the Strainer!)\n3. Use a playful font to convey friendliness and approachability, ensuring legibility against the background.\n\n**Overall Composition:**\n- Position the water pitcher slightly off-center to draw the viewer\'s eye, with the text placed strategically around it without overcrowding the image.\n- The background should remain subtle but inviting, ensuring that the focus stays on the product.\n- Use a slight shadow effect on the text to make it stand out against the background and maintain readability.\n- Visual balance is essential, so avoid cluttering the thumbnail with too many elements—focus on showcasing the main features of the product invitingly and engagingly.\n\nThis visually appealing and informative thumbnail will attract viewers\' attention and effectively communicate the benefits of using the 실생수 for making delicious barley tea.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Image:** A visually appealing close-up shot of the 실생수 (filtering water pitcher), showcasing its ergonomic handle and lightweight design. The pitcher should be filled with clear water, with a few floating barley grains to highlight its use for brewing 보리차 (barley tea).\n  \n2. **Background Elements:** A kitchen countertop background with a hint of greenery (such as a potted plant or herbs) to create a homey and fresh atmosphere. A steaming cup of 보리차 should be in the foreground, with a small stack of barley grains to the side.\n\n3. **Accessories:** Include an artistic representation of the filter inside the pitcher, showing how it effectively filters the barley grains.\n\n**Color Scheme:**\n- **Primary Colors:** Soft greens and warm browns to evoke a sense of nature and health.\n- **Accent Colors:** Light blues and whites for a clean and refreshing look, resembling water.\n- **Text Color:** Bright contrasting colors for text overlay, like white or yellow with a slight shadow for better visibility against the background.\n\n**Text Overlay Suggestions (in Korean):**\n1. **Main Title:** "편리하고 안전한 실생수!" (Convenient and Safe Filtering Water!)\n2. **Subtitle:** "보리차 만들기 꿀팁" (Tips for Making Barley Tea)\n\n**Overall Composition:**\n- The **pitcher** should be centered, slightly tilted to show off its features. \n- The **cup of 보리차** should be positioned on one side, slightly overlapping with the pitcher to create depth.\n- **Text overlays** should be strategically placed at the top and bottom, ensuring they do not obscure the main visuals. The main title can be at the top with a larger font, while the subtitle can be smaller but bold at the bottom.\n- Consider adding a glowing or shadow effect around the pitcher to make it stand out even more.\n  \nThis composition should attract viewers by highlighting the practicality and innovative features of the 실생수 while also visually representing the delightful experience of making and enjoying 보리차.',
#   "**YouTube Thumbnail Visual Prompt:**\n\n**Main Visual Elements:**\n1. **Central Image:** A high-quality image of the 실생수 (a specific type of water pot) prominently placed in the center. The pot should be shown filled with barley tea, with steam rising gently from the surface to suggest warmth and freshness. \n2. **Background:** A blurred kitchen or tea-making environment to create a cozy, homely atmosphere, with soft highlights that suggest natural light. Incorporate hints of barley grains scattered around the background to visually connect with the topic.\n3. **Floating Textures:** Include subtle, semi-transparent graphic elements like barley grains or tea leaves near the edges of the thumbnail to enrich the visual context.\n\n**Color Scheme:**\n- **Primary Colors:** Warm earthy tones (light beige, soft browns) to evoke a natural and organic feel. \n- **Accent Colors:** Splashes of green (to suggest freshness) and light amber (to represent the color of brewed tea).\n- **Text Color:** Use contrasting colors for the text, such as deep brown or dark green against the warm background to ensure readability.\n\n**Text Overlay Suggestions (in Korean):**\n1. Main Title Text: “저희 실생수와 보리차의 비밀!” (The Secret of Our 실생수 and Barley Tea!)\n   - Suggested Font: Bold, playful font that is easy to read with a slight curvature to suggest warmth and friendliness.\n   - Placement: Positioned near the top to ensure it catches attention first.\n  \n2. Subtitle Text: “쉽고 안전한 보리차 만들기” (Easy and Safe Barley Tea Making)\n   - Suggested Font: Slightly smaller, simple sans-serif font for clarity.\n   - Placement: Just below the main title, creating a visual hierarchy.\n\n**Overall Composition:**\n- The central image should dominate the visual space, with text overlay strategically placed to avoid obscuring key visual elements.\n- Create a balanced composition by ensuring that the text does not compete with the visual elements but instead complements them.\n- Use drop shadows or outlines on the text to enhance visibility against the background.\n- Ensure a slight vignette effect around the edges to draw the viewer's focus toward the center of the thumbnail.\n\nThis combination of visual elements, colors, and carefully crafted text is designed to attract viewers, conveying both the essence of the product and the inviting experience of making barley tea.",
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n- A large, eye-catching image of the 실생수 (filtering water pitcher) prominently displayed in the center. It should be shown in an appealing angle that highlights its convenient handle and the built-in filter.\n- Include a close-up illustration or real-life photo of the barley grains (보리알갱이) next to the pitcher to emphasize its feature for making barley tea (보리차).\n- Add a steaming, fresh cup of barley tea next to the pitcher to showcase the end product the audience can expect.\n- Optional: A light, blurred background of a cozy kitchen setting to convey a homey feeling or a nature-oriented backdrop to associate with the healthy aspect of the barley tea.\n\n**Color Scheme:**\n- Use warm, inviting colors like soft browns, yellows, and earthy greens to create a sense of comfort and health.\n- Add splashes of white and light blue to enhance the visual appeal and make the image feel fresh and clean.\n\n**Text Overlay Suggestions (Korean Text):**\n- Main text: "편리한 물따르기!" (Convenient Water Pouring!)\n  - Font: Bold and modern, easy to read, placed at the top of the thumbnail.\n- Additional text: "보리차 만들기 꿀팁!" (Barley Tea Making Tips!)\n  - Font: Slightly smaller, complementary style, placed at the bottom or sides to balance the composition.\n\n**Overall Composition:**\n- The pitcher should be the focal point, occupying the central area of the thumbnail.\n- Balance the layout by placing the related images (barley grains and tea cup) on either side of the main product to create symmetry.\n- Text should be strategically positioned to ensure it stands out without obstructing the visuals of the products.\n- Utilize a drop shadow or outline effect for the text to enhance legibility against the background.\n- Overall, the composition should be vibrant, engaging, and informative to draw viewers\' attention quickly and encourage clicks.',
#   "### YouTube Thumbnail Visual Prompt\n\n#### Main Visual Elements:\n1. **Central Image**: A well-designed, modern water-filling jug featuring an ergonomic handle and a mesh strainer prominently displayed. The jug should look user-friendly and appealing, positioned slightly tilted to showcase the strainer with barley grains spilling out or around it.\n   \n2. **Background**: A blurred kitchen countertop setting to create a warm and inviting atmosphere. A soft-focus kettle and herbal plants can be included subtly in the background to emphasize a natural theme.\n\n3. **Highlight Details**: Illustrate droplets of water flowing smoothly from the jug’s spout, emphasizing the ease of pouring. A subtle glow or sparkle effect around the jug can add visual appeal.\n\n#### Color Scheme:\n- **Primary Colors**: Soft pastel shades like mint green and sky blue for a fresh and clean look.\n- **Accent Colors**: Use warm yellows and earthy browns for barley and complement the background, creating a contrast that catches the eye.\n- **Text Colors**: Bold white or dark green text to stand out against the background.\n\n#### Text Overlay Suggestions (Korean Text):\n- Top Text: “편리한 물 따르기!” (Convenient Water Pouring!)\n- Bottom Text: “거름망으로 쉽게 보리차 만들기” (Easily Make Barley Tea with Strainer)\n\n#### Overall Composition:\n- Place the central image of the water jug slightly off-center (to the left).\n- The top text should arch over the jug, ensuring it doesn’t obstruct the view of the main visual.\n- The bottom text can be placed on the lower right corner in a balanced manner, ensuring it’s clear and readable.\n- Consider using a slight drop shadow on the text for better visibility against the background.\n- Add a subtle border or frame that complements the color scheme, enhancing overall attractiveness without being too distracting. \n\nThis combination of elements will create an eye-catching thumbnail that effectively conveys the product's appeal and encourages viewers to click and learn more.",
#   '**YouTube Thumbnail Visual Prompt for "실생수"**\n\n**Main Visual Elements:**\n1. **Product Showcase:** Place a high-quality image of the "실생수" product prominently in the center. The product should be depicted in an attractive angle that highlights its convenient handles and strainer feature. \n2. **Action Shot:** Incorporate an additional image of someone effortlessly pouring from the product, showcasing the ease of use and preventing spills. This could be a hand with the product and a cup just below it.\n3. **Background:** Use a light kitchen or beverage preparation background that suggests an inviting environment, perhaps with barley tea ingredients (e.g., barley grains or tea leaves) to reinforce the product\'s purpose.\n\n**Color Scheme:**\n- Utilize a warm and inviting color palette with soft earthy tones such as beige, light brown, and pale green to represent natural ingredients like barley.\n- Add pops of brighter colors (e.g., saturated yellows or greens) for the text overlay to ensure it stands out against the softer background.\n- Incorporate a subtle gradient behind the product, transitioning from light beige to white for a clean, professional look.\n\n**Text Overlay Suggestions (Korean Text):**\n1. **Top Section:** "완벽한 차 만들기!" (Perfect Tea Making!) - Bold and eye-catching font, potentially in a bright yellow or white with a slight shadow to enhance readability.\n2. **Bottom Section:** "실생수의 편리함" (Convenience of 실생수) - Use a slightly smaller font size in a contrasting color, perhaps dark green or navy blue, ensuring it complements the primary text but remains readable.\n\n**Overall Composition:**\n- Position the product image slightly off-center to the right to create a dynamic flow, with the action shot (pouring tea) on the left, leading the viewer’s eye toward the product.\n- Text elements should be placed strategically at the top and bottom to balance the composition without overcrowding the image. The top text should be larger to capture attention first, while the bottom text reinforces the message of convenience.\n- Ensure ample whitespace around the edges of the thumbnail to avoid a cluttered appearance, focusing the viewer\'s attention on the key elements (product, action, and text).\n\nThis detailed visual prompt will help create an engaging and attractive thumbnail that promotes the usability and efficiency of "실생수" and catches the attention of potential viewers on YouTube.',
#   '### YouTube Thumbnail Visual Prompt for "실생수"\n\n#### Main Visual Elements:\n1. **Product Showcase**: The central focus should be a high-quality image of the "실생수" product, prominently displaying the convenient handles and built-in strainer. The product should be shown in a dynamic angle to highlight its usability and design.\n  \n2. **Background Scene**: Create a soft-focus kitchen setting in the background to convey an atmosphere of warmth and usability. You could suggest elements such as a wooden table, a kettle, and barley grains to reinforce the tea-making theme.\n\n3. **User Interaction**: Include an illustrated hand or silhouette using the product (pouring tea into a cup) to emphasize the ease of use and functionality.\n\n#### Color Scheme:\n- **Primary Colors**: Use warm earthy tones like beige, light brown, and soft greens to evoke a sense of comfort and connection to nature. These colors will also complement the barley tea theme.\n- **Accent Colors**: Utilize brighter colors such as yellow for highlights and text elements, creating contrast and drawing the viewer\'s eyes to key details.\n\n#### Text Overlay Suggestions (Korean Text):\n1. **Main Title**: \n   - "편리한 수조!" (Convenient Water Container!)\n   - Use a bold font, white letters with a slight shadow for readability against the background.\n\n2. **Subtitle**: \n   - "쉽고 빠른 보리차!" (Easy & Quick Barley Tea!)\n   - Place this below the main title in a smaller font size, possibly in a warmer hue like soft yellow or green to stand out but not overshadow the main title.\n\n#### Overall Composition:\n- Position the product slightly off-center to the right to create a dynamic composition while leaving space on the left for the text. \n- The background should have a depth of field effect, making the product the focal point while softly indicating the theme of the kitchen.\n- The text should be easily readable, with no clutter around it, ensuring that viewers can immediately grasp the message.\n- Consider adding a small logo or icon in one corner to enhance brand recognition without detracting from the product display.\n\nBy combining these visual elements thoughtfully, the thumbnail will attract viewers by highlighting both the product\'s functionality and the enjoyable experience of making barley tea.',
#   '**YouTube Thumbnail Visual Prompt for "실생수" Product**\n\n**Main Visual Elements:**\n1. **Product Focus:** A clear, high-resolution image of the "실생수" product, prominently displayed in the center. The product should be slightly angled to showcase its convenient handles and integrated strainer.\n2. **Barley Tea Elements:** Include an overflowing cup of barley tea beside the product, with a few tea leaves scattered around to signify freshness. The steam rising from the cup should be visible, suggesting warmth and inviting viewers in.\n3. **Background Elements:** Subtle images of a kitchen setting in the background, with soft, blurred edges, creating a cozy atmosphere without distracting from the main product. \n\n**Color Scheme:**\n- **Primary Colors:** Soft pastel colors like mint green and light beige to suggest freshness and warmth.\n- **Accent Colors:** Rich brown tones representing barley tea, providing contrast and drawing attention to the beverage.\n- **Text Color:** Vibrant white or light yellow for the text overlay, ensuring it stands out against the background.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Main Headline: "편리함과 효율성!" (Convenience and Efficiency!) \n   - Positioned at the top of the thumbnail in bold, eye-catching font.\n2. Subheading: "완벽한 보리차 준비!" (Perfect Barley Tea Preparation!)\n   - Placed below the main headline in slightly smaller font, perhaps in a cursive or softer style for a friendly appeal.\n\n**Overall Composition:**\n- The product image should be centered with the cup of barley tea to the right of it, creating a balanced look. \n- The text should be layered in a way that it does not obstruct the view of the product but instead enhances its appeal.\n- The overall layout should maintain a clean, uncluttered feel, with enough white space around the edges to keep the viewer\'s focus on the **"실생수"** product and the accompanying graphics.\n- Consider adding a subtle drop shadow effect to the product and text to give them depth and make them pop out from the background. \n\nThis carefully designed thumbnail will attract viewers by emphasizing the practicality of the "실생수" while inviting them to explore its benefits in beverage preparation.',
#   '**YouTube Thumbnail Visual Prompt**\n\n**Main Visual Elements:**\n1. **Central Product Image:** Place a high-quality image of the "실생수" product prominently in the center. The product should be shown with its handles visible, highlighting its ergonomic design. Include the strainer element, maybe placed beside or slightly behind the main product to indicate its functionality.\n   \n2. **Contextual Background:** Use a blurred background that depicts a kitchen setting or a cozy tea-drinking environment. This adds context and makes the thumbnail relatable. You could include a steaming cup of barley tea to signify the product\'s primary use.\n\n3. **Action Visuals:** Include a hand reaching to pour from the product, emphasizing its easy-to-use features. Additionally, add small visual effects such as splashes to convey movement and action, making it appear as though the pouring is smooth and spill-proof.\n\n**Color Scheme:**\n- **Warm Colors:** Use a warm and inviting color palette that includes shades of soft browns, creams, and light greens to evoke feelings of comfort and homeliness. \n- **Accent Colors:** Include light accents of gold or bright teal to make the thumbnail pop and draw attention to specific areas, particularly around the product and text overlays.\n\n**Text Overlay Suggestions (Korean Text):**\n1. Title: "편리한 사용성!" (Convenient Usability!)\n2. Subtitle: "완벽한 보리차 준비!" (Perfect Barley Tea Preparation!)\n3. Optional Call to Action: "지금 확인하세요!" (Check It Out Now!)\n\n**Overall Composition:**\n- Arrange the product centrally, with primary text (the title) at the top in a bold, easy-to-read font (white or yellow with a dark shadow for contrast). Place the subtitle below it in a slightly smaller font.\n- Use the bottom area for the call-to-action, employing a contrasting banner or bright background stripe to make it stand out.\n- Ensure that there’s a balanced flow where viewers’ eyes move from the product to the text seamlessly.\n- Leave some negative space around text areas for clarity and emphasis, reducing visual clutter and enhancing overall readability.\n\nThis composition not only highlights the product\'s usability but also creates an inviting atmosphere, enticing viewers to click on the video for more information.',
#   '**YouTube Thumbnail Visual Prompt:**\n\n**Main Visual Elements:**\n1. **Product Focus**: Showcase the "실생수" product prominently in the center, highlighting its handles and strainer. Arrange the product at an angle to create depth.\n2. **Background**: Use a softly blurred kitchen setting to emphasize a lifestyle aspect, indicating that the product is practical for everyday use.\n3. **Beverage Visual**: To the side of the product, include a clear glass of freshly made barley tea, possibly with ice and a slice of lemon, to demonstrate the end-use of the product. \n\n**Color Scheme:**\n- Use a warm and inviting color palette. \n  - **Main colors**: Soft greens and browns (reflecting barley tea and natural materials).\n  - **Accent colors**: Light cream or beige for background to create contrast and make the product pop.\n  - **Text colors**: Utilize a combination of bold dark green and vibrant yellow to draw attention to text overlays and ensure readability.\n\n**Text Overlay Suggestions (Korean Text):**\n- Main Text: "쉽고 편리한 사용!" (Easy and Convenient to Use!)\n  - Font: Bold and modern sans-serif for impact, colored in dark green.\n- Subtext: "완벽한 보리차 만들기" (Perfect for Making Barley Tea)\n  - Font: Italicized or lighter weight sans-serif, colored in a contrasting yellow to complement the main text.\n\n**Overall Composition:**\n- Ensure the thumbnail is not overcrowded; the product should be the focal point with clear viewing angles.\n- Place the main text at the top of the thumbnail in a large font, keeping it concise and engaging.\n- Position the subtext towards the bottom of the image to provide additional information without overshadowing the main message.\n- Include a small call-to-action overlay, such as a "Watch Now!" badge in a corner, colored in a bright contrasting color (like red or bright orange) for emphasis.\n- The overall look should convey a sense of warmth, functionality, and trust, inviting viewers to learn more about this convenient product.'],
#  'thumbnail_sketches': ['thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg',
#   'thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg',
#   'thumbnail_1.jpg',
#   'thumbnail_2.jpg',
#   'thumbnail_3.jpg',
#   'thumbnail_4.jpg',
#   'thumbnail_5.jpg'],
#  'final_summary': 'The summaries collectively highlight the features of a product called "실생수." It is designed for easy use thanks to its convenient handles, making it suitable for pouring without the risk of spills due to its weight. Additionally, the product includes a strainer, which facilitates the preparation of barley tea. Overall, it is highly recommended for its usability and efficiency in making beverages.',
#  'user_feedback': 'Give it a more vibrant color palette and make the text more accurate.',
#  'chosen_prompt': '### YouTube Thumbnail Visual Prompt\n\n**Main Visual Elements:**\n1. **Central Image of the Water Dispenser:**\n   - An eye-catching, high-quality image of the water dispenser in use. Show it being poured, with water flowing from the spout into a clear, styled glass. The dispenser should prominently feature the convenient handle and filter.\n  \n2. **Background Elements:**\n   - A light, refreshing background that suggests cleanliness and hydration. Consider using a blurred kitchen or outdoor setting that evokes a sense of freshness.\n   - Subtle illustrations or icons of barley grains or tea leaves in one corner, representing the filtering aspect of the product.\n\n3. **Additional Visual Elements:**\n   - Include a small badge or circular icon that says "Best Seller!" or "Recommended!" to create a sense of trust and urgency.\n\n**Color Scheme:**\n- **Primary Colors:** Use shades of light blue and white for a clean, refreshing feel. Light green accents to represent nature and the barley tea aspect.\n- **Contrast Colors:** Bright orange or yellow for the badge/icon to attract attention.\n  \n**Text Overlay Suggestions (Korean Text):**\n- Main Title: "가볍고 편리한 물 디스펜서!" (Lightweight and Convenient Water Dispenser!)\n- Subtitle: "보리차 준비가 간편해요!" (Easy to Brew Barley Tea!)\n- Use bold, easy-to-read fonts with a slight drop shadow for clear visibility.\n\n**Overall Composition:**\n- Position the water dispenser centrally to make it the focal point. \n- Place the title text at the top of the thumbnail to draw the viewer\'s attention immediately, slightly arched or in a horizontal banner.\n- Position the subtitle at the bottom, ensuring it’s legible against the background.\n- Balance the layout by placing the badge/icon in an upper corner, enhancing viewer focus without distracting from the main elements.\n- Ensure that the entire design is vibrant and appealing, with balanced spacing and emphasis on key components. Use a subtle gradient in the background to add depth without clutter.'}
